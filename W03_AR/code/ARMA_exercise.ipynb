# %% [markdown]
# # Exercise

# %% [markdown]
# try to uncover the underlying connectivity strengths in the network, you can access the data from `ntx_mvar.npy` (contains noise driven data), and `ntx_mvar_oscillation.npy` (contains oscillatory driven data). For the oscillatory driven data, compute coherence using the multitaper function and identify the oscillatory modes and connections among channels (coherence graph).
#
# Fit and MVAR model (of order 2) in both data cases.
# You should notice that two of the nodes have high correlation.
# Compute granger causality graph (ratio of variance explained by restricted and unrestricted MVAR)
#
# Let's say you want to check if node 4 has a causal influence on node 1, then to check the strength of this causal direction you can regress node 1 once against nodes 1,2,3,4 (unrestricted case)
# and once against nodes 1,2,3 (restricted case). And compute the ratio of variance explained or goodness of fit of the two models.

# %% [markdown]
# # Tutorial

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate ARMA(2,1) data with phi1 = 0.5, phi2 = -0.5, theta1 = 0.1
np.random.seed(1234)
n = 1000
phi = np.array([0.5, -0.5])
theta = np.array([0.1])
sigma = 0.01
mu = 0
y = 10 * np.ones(n)
e = np.random.normal(mu, sigma, n)
for i in range(2, n):
    y[i] = phi[0]*y[i-1] + phi[1]*y[i-2] + e[i] + theta[0]*e[i-1]

# Plot the data
plt.plot(y, '-x')
plt.title("ARMA(2,1) Data")
plt.xlabel("Time")
plt.ylabel("y")
plt.xlim([0, 20])

# add coefficient values to the plot using variables
# phi1, phi2, theta1, sigma
plt.text(1.1, 0.7, r'$\phi_1 =' +f'{phi[0]}'+'$', transform=plt.gca().transAxes)
plt.text(1.1, 0.6, r'$\phi_2 =' +f'{phi[1]}'+'$', transform=plt.gca().transAxes)
plt.text(1.1, 0.5, r'$\theta_1 =' +f'{theta[0]}'+'$', transform=plt.gca().transAxes)

# write the equation of the model
plt.text(1.1, 0.3, r'$y_t = \phi_1 y_{t-1} + \phi_2 y_{t-2} + \epsilon_t + \theta_1 \epsilon_{t-1}$', transform=plt.gca().transAxes)
plt.show()

# %%
# fit an ARIMA(2,1) model to the data
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(y, order=(2,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 432.789
# Date:                Sat, 25 Nov 2023   AIC                           -857.577
# Time:                        14:07:47   BIC                           -837.950
# Sample:                             0   HQIC                          -850.117
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5283      0.009     59.935      0.000       0.511       0.546
# ar.L2         -0.9986      0.001  -1550.348      0.000      -1.000      -0.997
# ma.L1          0.8632      0.016     54.994      0.000       0.832       0.894
# sigma2         0.0243      0.000     72.806      0.000       0.024       0.025
# ===================================================================================
# Ljung-Box (L1) (Q):                  48.92   Jarque-Bera (JB):          15329497.96
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.03   Skew:                           -20.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                       608.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# plot the residuals
plt.plot(model_fit.resid, '-x')

# %%
# partial autocorrelation function of the signal (PACF) to determine the order of the AR model
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(y, lags=20)
plt.show()

# %% [markdown]
# ## Example Network Data

# %%
# directed graph with three nodes
import networkx as nx
G = nx.DiGraph()
nvar = 4
G.add_nodes_from([1, 2, 3, 4])
G.add_edges_from([(1, 2), (1, 3), (4, 3), (1,1), (2, 2), (3,3), (4,4)])
nx.draw(G, with_labels=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# get the adjacency matrix
adj = nx.adjacency_matrix(G).todense()

# x is the state vector, 
# u is the background input - sample from 4D normal distribution with mean 0 and covariance matrix with off-diagonal elements 0.1

# define the covariance matrix
ucov = 0.9 * np.eye(4) + 0.1 * np.ones((4, 4))
sigma = 0.1

N = 1000
fs = 1000
u = np.random.multivariate_normal(np.zeros(4), ucov, N).T

# initialize the state vector
x = np.zeros((4, N))

# define the state transition matrix

def generate_A(adj):
    A = np.random.randn(4,4) * 0.7 
    A[np.where(adj==0)] = 0

    # set the diagonal elements to 0.5
    A[np.diag_indices(4)] = np.random.randn(4) * 0.2
    return A

order = 2
# generate list of `order` state transition matrices
A = [generate_A(adj.T) for i in range(order)]

# assign as edge weights in the graph
for i in range(4):
    for j in range(4):
        if adj[i, j] == 1:
            G[i+1][j+1]['weight'] = A[0][i, j]

# pure oscillation at f0 Hz assuming sampling rate of fs
f0 = 80
amp_noise = (np.random.randn(N)*0.3 + 1)
oscil_y = amp_noise * np.sin(np.sin(2*np.pi*(f0)*np.arange(N)/fs))


# iterate over time
for t in range(4, N):
    # add the oscillation to node 1
    x[0, t] += oscil_y[t]
    x[:, t] += sigma*u[:, t]
    for i in range(order):
        x[:, t] += A[i] @ x[:, t-i-1]

# %%
# plot directed graph with transition matrix values on the edges
nx.draw(G, with_labels=True)
labels = nx.get_edge_attributes(G,'weight')
# round labels to 2 decimal places
labels = {k: round(v, 2) for k, v in labels.items()}
nx.draw_networkx_edge_labels(G, pos=nx.spring_layout(G), edge_labels=labels)
plt.show()

# print A with 2 decimal places
print(np.round(A, 2))
# Out:
# [[[ 0.11  0.    0.    0.  ]
#   [ 0.   -0.3   0.    0.  ]
#   [ 0.    0.    0.08  0.  ]
#   [ 0.    0.    0.   -0.11]]
#
#  [[ 0.09  0.    0.    0.  ]
#   [ 0.    0.19  0.    0.  ]
#   [ 0.    0.    0.4   0.  ]
#   [ 0.    0.    0.   -0.1 ]]]

# %%
# eigenvalues of A
print(np.linalg.eigvals(A))
# Out:
# [[ 0.11177067 -0.30431907  0.07931496 -0.11243753]
#  [ 0.09463012  0.18527608  0.40412768 -0.1037067 ]]

# %%
# plot nodes with labels
plt.plot(x.T)
plt.legend(['1', '2', '3', '4'])
plt.xlabel("Time")
plt.xlim([0, 100])
plt.show()

# %% [markdown]
# ## MVAR

# %%
# fit MVAR model to the data

import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# fit VAR model with order 2
model = VAR(x.T)
results = model.fit(2)
print(results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 25, Nov, 2023
# Time:                     14:37:03
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -15.6156
# Nobs:                     998.000    HQIC:                  -15.7253
# Log likelihood:           2252.08    FPE:                1.38480e-07
# AIC:                     -15.7925    Det(Omega_mle):     1.33595e-07
# --------------------------------------------------------------------
# Results for equation y1
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.003093         0.011865            0.261           0.794
# L1.y1         1.204956         0.027871           43.233           0.000
# L1.y2        -0.134639         0.117682           -1.144           0.253
# L1.y3        -0.265652         0.113362           -2.343           0.019
# L1.y4        -0.241586         0.116939           -2.066           0.039
# L2.y1        -0.478284         0.027831          -17.185           0.000
# L2.y2        -0.137310         0.117514           -1.168           0.243
# L2.y3         0.140353         0.113426            1.237           0.216
# L2.y4        -0.032303         0.117167           -0.276           0.783
# ========================================================================
#
# Results for equation y2
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.003588         0.003211            1.118           0.264
# L1.y1        -0.008516         0.007542           -1.129           0.259
# L1.y2        -0.315580         0.031844           -9.910           0.000
# L1.y3        -0.012962         0.030675           -0.423           0.673
# L1.y4        -0.006483         0.031643           -0.205           0.838
# L2.y1         0.015918         0.007531            2.114           0.035
# L2.y2         0.129878         0.031799            4.084           0.000
# L2.y3        -0.028790         0.030692           -0.938           0.348
# L2.y4         0.002354         0.031705            0.074           0.941
# ========================================================================
#
# Results for equation y3
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.000196         0.003094            0.063           0.950
# L1.y1        -0.011169         0.007267           -1.537           0.124
# L1.y2         0.020957         0.030684            0.683           0.495
# L1.y3         0.051831         0.029558            1.754           0.080
# L1.y4         0.039526         0.030490            1.296           0.195
# L2.y1         0.017564         0.007257            2.420           0.016
# L2.y2         0.021324         0.030641            0.696           0.486
# L2.y3         0.375096         0.029574           12.683           0.000
# L2.y4        -0.036176         0.030550           -1.184           0.236
# ========================================================================
#
# Results for equation y4
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const        -0.004068         0.003202           -1.270           0.204
# L1.y1        -0.010130         0.007522           -1.347           0.178
# L1.y2         0.019580         0.031761            0.616           0.538
# L1.y3         0.023864         0.030595            0.780           0.435
# L1.y4        -0.113737         0.031560           -3.604           0.000
# L2.y1         0.009564         0.007511            1.273           0.203
# L2.y2         0.031000         0.031715            0.977           0.328
# L2.y3        -0.026061         0.030612           -0.851           0.395
# L2.y4        -0.175624         0.031622           -5.554           0.000
# ========================================================================
#
# Correlation matrix of residuals
#             y1        y2        y3        y4
# y1    1.000000  0.055520  0.008205  0.009618
# y2    0.055520  1.000000  0.114846  0.121859
# y3    0.008205  0.114846  1.000000  0.071376
# y4    0.009618  0.121859  0.071376  1.000000

# %%
# separate the parameters for each lag
k = 0
bias = results.params[0]
A_fit = []
for j in range(order):
    A_fit.append(results.params[1+k:1+k+nvar])
    k += nvar

# %%
# disp_A = lambda A: print(np.round(A, 2))
# plot to compare A_fit and A
plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(A[0].T)
plt.title("True A1")
plt.subplot(1, 2, 2)
plt.imshow(A_fit[0])
plt.title("Estimated A1")
plt.show()

# plot to compare A_fit and A
plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(A[1].T)
plt.title("True A2")
plt.subplot(1, 2, 2)
plt.imshow(A_fit[1])
plt.title("Estimated A2")
plt.show()

# %%
# plot the residuals
plt.plot(results.resid, '-x')
plt.show()

# %%
A_fit_arr = np.array(A_fit)
# pad with zeros to get 1000 samples
# Fourier transform of the MVAR coefficients
nfft = 1000
A_fit_fft = np.fft.fft(A_fit_arr, n=nfft, axis=0)

# %%
# partial directed coherence (PDC) of the MVAR coefficients

identity_mat = np.repeat(np.expand_dims(np.eye(nvar), axis=0), nfft, axis=0)
A_fit_bar_fft = (identity_mat - A_fit_fft)
pdc = A_fit_bar_fft / np.sqrt((np.abs(A_fit_bar_fft)**2).sum(axis=1, keepdims=True))

# %%
pdc = np.zeros_like(A_fit_fft)
for i in range(4):
    for j in range(4):
        pdc[:, i, j] = np.abs(A_fit_fft[:, i, j]) / np.sqrt(np.sum(np.abs(A_fit_fft[:, :, j])**2, axis=1))

# %% [markdown]
# ## Coherence

# %% [markdown]
# ### Cross-spectral density

# %%
import mne.time_frequency as mnetf

# compute the spectral density matrix of the network data x

# define the frequency range
fmin = 0
fmax = 100

# %%
# tapered data
# def psd_array_multitaper(x, sfreq, fmin=0.0, fmax=np.inf, bandwidth=None,
#                          adaptive=False, low_bias=True, normalization='length',
#                          output='power', n_jobs=None, verbose=None):
"""Compute power spectral density (PSD) using a multi-taper method.

Parameters
----------
x : array, shape=(..., n_times)
    The data to compute PSD from.
sfreq : float
    The sampling frequency.
fmin : float
    The lower frequency of interest.
fmax : float
    The upper frequency of interest.
bandwidth : float
    The bandwidth of the multi taper windowing function in Hz.
adaptive : bool
    Use adaptive weights to combine the tapered spectra into PSD
    (slow, use n_jobs >> 1 to speed up computation).
low_bias : bool
    Only use tapers with more than 90%% spectral concentration within
    bandwidth.
%(normalization)s
output : str
    The format of the returned ``psds`` array. Can be either ``'complex'``
    or ``'power'``. If ``'power'``, the power spectral density is returned.
    If ``output='complex'``, the complex fourier coefficients are returned
    per taper.
%(n_jobs)s
%(verbose)s

Returns
-------
psds : ndarray, shape (..., n_freqs) or (..., n_tapers, n_freqs)
    The power spectral densities. All dimensions up to the last (or the
    last two if ``output='complex'``) will be the same as input.
freqs : array
    The frequency points in Hz of the PSD.
weights : ndarray
    The weights used for averaging across tapers. Only returned if
    ``output='complex'``.

See Also
--------
mne.io.Raw.plot_psd
mne.Epochs.plot_psd
csd_multitaper
psd_multitaper

Notes
-----
.. versionadded:: 0.14.0
"""

# compute the tapered spectra
ft_ensemble, freqs, weights = mnetf.psd_array_multitaper(x, sfreq=fs, fmin=fmin, fmax=fmax, bandwidth=10, adaptive=False, low_bias=True, normalization='length', output='complex', n_jobs=1, verbose=True)
# Out:
#     Using multitaper spectrum estimation with 9 DPSS windows

# %%
print(ft_ensemble.shape)
# 4 nodes, 9 tapers, 101 frequencies
# this is our ensemble (size 9) of fourier transforms for that data segment for each node.
# Out:
# (4, 9, 101)

# %%
# we can average over the ensemble (tapers) to get the power spectral density for each node

plt.plot((np.abs(ft_ensemble)**2 * weights).sum(axis=1).T)
plt.legend(['1', '2', '3', '4'])
plt.show()

# %%
def get_psd_ensemble(ft_enemble):
    psd_ensemble = np.abs(ft_enemble)**2
    return psd_ensemble

def get_csd_ensemble(ft_enemble_x, ft_enemble_y):
    csd_ensemble_xy = np.expand_dims(ft_enemble_x, axis=1) * np.expand_dims(np.conj(ft_enemble_y), axis=0)
    return csd_ensemble_xy

def coherence(fts_x, fts_y):
    c_xy = get_csd_ensemble(fts_x, fts_y).mean(axis=2)
    psd_x = get_psd_ensemble(fts_x).mean(axis=1)
    psd_y = get_psd_ensemble(fts_y).mean(axis=1)
    psd_xy = np.expand_dims(psd_x, axis=1) * np.expand_dims(psd_y, axis=0)
    coh = c_xy/np.sqrt(psd_xy)
    return coh

# %%
coh = coherence(ft_ensemble, ft_ensemble)

# %%
plt.imshow(np.abs(coh).sum(axis=-1))
# add ticks 1 to 4
plt.xticks(np.arange(4), np.arange(1, 5))
plt.yticks(np.arange(4), np.arange(1, 5))

# add xlabel and ylabel presynaptic and postsynaptic
plt.xlabel("Source Node")
plt.ylabel("Target Node")
plt.show()

# %%
plt.plot(np.abs(coh[0].T))
plt.legend(['1', '2', '3', '4'])
plt.show()

# %% [markdown]
# ## Linear Granger Causality

# %% [markdown]
# uncover the directed graph using granger causality

# %%
plt.imshow(np.abs(pdc.sum(axis=0)))

# %%
from statsmodels.tsa.stattools import grangercausalitytests
granger_map = np.zeros((nvar, nvar))
for i in range(nvar):
    for j in range(nvar):
        if i!=j:
            g = grangercausalitytests(x.T[:, [i, j]], 2, addconst=True, verbose=None)
            granger_map[i, j] = g[1][0]['params_ftest'][0]
        # = g[1][0]['ssr_ftest'][1]
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1327  , p=0.2875  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=1.1361  , p=0.2865  , df=1
# likelihood ratio test: chi2=1.1355  , p=0.2866  , df=1
# parameter F test:         F=1.1327  , p=0.2875  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6782  , p=0.1872  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=3.3732  , p=0.1851  , df=2
# likelihood ratio test: chi2=3.3676  , p=0.1857  , df=2
# parameter F test:         F=1.6782  , p=0.1872  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.0519  , p=0.0080  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=7.0731  , p=0.0078  , df=1
# likelihood ratio test: chi2=7.0482  , p=0.0079  , df=1
# parameter F test:         F=7.0519  , p=0.0080  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8532  , p=0.0215  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=7.7451  , p=0.0208  , df=2
# likelihood ratio test: chi2=7.7152  , p=0.0211  , df=2
# parameter F test:         F=3.8532  , p=0.0215  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.1475  , p=0.0420  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=4.1600  , p=0.0414  , df=1
# likelihood ratio test: chi2=4.1514  , p=0.0416  , df=1
# parameter F test:         F=4.1475  , p=0.0420  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8166  , p=0.0603  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=5.6616  , p=0.0590  , df=2
# likelihood ratio test: chi2=5.6456  , p=0.0594  , df=2
# parameter F test:         F=2.8166  , p=0.0603  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3363  , p=0.2480  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=1.3403  , p=0.2470  , df=1
# likelihood ratio test: chi2=1.3394  , p=0.2471  , df=1
# parameter F test:         F=1.3363  , p=0.2480  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7262  , p=0.0660  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=5.4798  , p=0.0646  , df=2
# likelihood ratio test: chi2=5.4648  , p=0.0651  , df=2
# parameter F test:         F=2.7262  , p=0.0660  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0823  , p=0.7743  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.0825  , p=0.7739  , df=1
# likelihood ratio test: chi2=0.0825  , p=0.7739  , df=1
# parameter F test:         F=0.0823  , p=0.7743  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5194  , p=0.5950  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=1.0440  , p=0.5933  , df=2
# likelihood ratio test: chi2=1.0435  , p=0.5935  , df=2
# parameter F test:         F=0.5194  , p=0.5950  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0023  , p=0.9615  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.0023  , p=0.9615  , df=1
# likelihood ratio test: chi2=0.0023  , p=0.9615  , df=1
# parameter F test:         F=0.0023  , p=0.9615  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0347  , p=0.9659  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=0.0697  , p=0.9658  , df=2
# likelihood ratio test: chi2=0.0697  , p=0.9658  , df=2
# parameter F test:         F=0.0347  , p=0.9659  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=0.9984  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=0.9984  , df=1
# likelihood ratio test: chi2=0.0000  , p=0.9984  , df=1
# parameter F test:         F=0.0000  , p=0.9984  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2099  , p=0.0408  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=6.4521  , p=0.0397  , df=2
# likelihood ratio test: chi2=6.4313  , p=0.0401  , df=2
# parameter F test:         F=3.2099  , p=0.0408  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0001  , p=0.9938  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.0001  , p=0.9938  , df=1
# likelihood ratio test: chi2=0.0001  , p=0.9938  , df=1
# parameter F test:         F=0.0001  , p=0.9938  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5162  , p=0.5970  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=1.0375  , p=0.5953  , df=2
# likelihood ratio test: chi2=1.0370  , p=0.5954  , df=2
# parameter F test:         F=0.5162  , p=0.5970  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0988  , p=0.1477  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=2.1051  , p=0.1468  , df=1
# likelihood ratio test: chi2=2.1029  , p=0.1470  , df=1
# parameter F test:         F=2.0988  , p=0.1477  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6842  , p=0.1861  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=3.3853  , p=0.1840  , df=2
# likelihood ratio test: chi2=3.3796  , p=0.1846  , df=2
# parameter F test:         F=1.6842  , p=0.1861  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0501  , p=0.8230  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.0502  , p=0.8227  , df=1
# likelihood ratio test: chi2=0.0502  , p=0.8227  , df=1
# parameter F test:         F=0.0501  , p=0.8230  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9441  , p=0.3894  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=1.8977  , p=0.3872  , df=2
# likelihood ratio test: chi2=1.8959  , p=0.3875  , df=2
# parameter F test:         F=0.9441  , p=0.3894  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2848  , p=0.5937  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.2856  , p=0.5930  , df=1
# likelihood ratio test: chi2=0.2856  , p=0.5931  , df=1
# parameter F test:         F=0.2848  , p=0.5937  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5545  , p=0.5746  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=1.1145  , p=0.5728  , df=2
# likelihood ratio test: chi2=1.1139  , p=0.5730  , df=2
# parameter F test:         F=0.5545  , p=0.5746  , df_denom=993, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2502  , p=0.6170  , df_denom=996, df_num=1
# ssr based chi2 test:   chi2=0.2510  , p=0.6164  , df=1
# likelihood ratio test: chi2=0.2509  , p=0.6164  , df=1
# parameter F test:         F=0.2502  , p=0.6170  , df_denom=996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5805  , p=0.5598  , df_denom=993, df_num=2
# ssr based chi2 test:   chi2=1.1668  , p=0.5580  , df=2
# likelihood ratio test: chi2=1.1661  , p=0.5582  , df=2
# parameter F test:         F=0.5805  , p=0.5598  , df_denom=993, df_num=2

# %%
im = plt.imshow(granger_map)
plt.colorbar(im)
plt.show()
